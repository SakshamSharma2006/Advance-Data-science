# %% [markdown]
# <a href="https://colab.research.google.com/github/SakshamSharma2006/Advance-Data-science/blob/main/LSTM(GTZAN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Libraries
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Define Keras layers
model = tf.keras.models.Sequential()
Dense = tf.keras.layers.Dense
Dropout = tf.keras.layers.Dropout
LSTM = tf.keras.layers.LSTM
Bidirectional = tf.keras.layers.Bidirectional

## Dataset
# The dataset is a CSV file containing audio features extracted from 3-second segments of music tracks across various genres.
# Each original song is split into approximately 10 segments, treated as sequences for LSTM input.
# Features include means and variances of chroma, RMS, spectral centroid, etc., up to MFCCs, totaling 57 features per segment.
df = pd.read_csv('features_3_sec.csv')

## Create train and test data
# Parse song ID from filename (e.g., 'blues.00000' from 'blues.00000.0.wav')
df['song_id'] = df['filename'].apply(lambda x: '.'.join(x.split('.')[:2]))

# Features columns (exclude filename, length, label, song_id)
feature_cols = [col for col in df.columns if col not in ['filename', 'length', 'label', 'song_id']]

# Scale features
scaler = StandardScaler()
df[feature_cols] = scaler.fit_transform(df[feature_cols])

# Group by song_id, assuming ~10 segments per song
grouped = df.groupby('song_id')
sequences = []
labels = []

for song_id, group in grouped:
    # Sort by segment (last part of filename)
    group = group.sort_values(by='filename')
    seq = group[feature_cols].values  # Shape: (num_segments, num_features)
    label = group['label'].iloc[0]    # Same label for all segments
    sequences.append(seq)
    labels.append(label)

# Pad sequences to max length (assuming max 10 segments)
max_seq_len = max(len(seq) for seq in sequences)
padded_sequences = np.array([np.pad(seq, ((0, max_seq_len - len(seq)), (0, 0)), mode='constant') for seq in sequences])

# Encode labels
le = LabelEncoder()
encoded_labels = le.fit_transform(labels)

# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(padded_sequences, encoded_labels, test_size=0.2, random_state=42)

# The features are scaled using StandardScaler for better model performance.
# Without scaling, the accuracy may decrease, and training could be less stable.
# The sequences are padded to ensure uniform input shape for LSTM.
# Input shape for LSTM will be (max_seq_len, num_features), e.g., (10, 57).

# Define the model
model.add(Bidirectional(LSTM(256, return_sequences=True, dropout=0.3), input_shape=(max_seq_len, len(feature_cols))))
model.add(Bidirectional(LSTM(256, dropout=0.3)))
model.add(Dropout(0.1))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(len(le.classes_), activation='softmax'))

# Define optimizer
optimizer = tf.keras.optimizers.AdamW(learning_rate=0.0005, weight_decay=1e-6)

# Compile model
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# The specification of loss='sparse_categorical_crossentropy' is crucial as our targets are integers, not one-hot encoded categories.
# Train the model
model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 231ms/step - accuracy: 0.2909 - loss: 2.0274 - val_accuracy: 0.4650 - val_loss: 1.5048
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - accuracy: 0.5246 - loss: 1.3453 - val_accuracy: 0.5750 - val_loss: 1.2323
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 200ms/step - accuracy: 0.6153 - loss: 1.0815 - val_accuracy: 0.6500 - val_loss: 1.0964
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - accuracy: 0.6179 - loss: 1.0305 - val_accuracy: 0.6400 - val_loss: 1.0808
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 235ms/step - accuracy: 0.6853 - loss: 0.9246 - val_accuracy: 0.6450 - val_loss: 1.0797
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 193ms/step - accuracy: 0.7007 - loss: 0.8672 - val_accuracy: 0.7000 - val_loss: 0.9693
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 232ms/step - accuracy: 0.7533 - loss: 0.7147 - val_accuracy: 0.7000 - val_loss: 1.0313
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - accuracy: 0.7488 - loss: 0.7226 - val_accuracy: 0.7150 - val_loss: 0.9102
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 235ms/step - accuracy: 0.7950 - loss: 0.6404 - val_accuracy: 0.7200 - val_loss: 0.8955
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 196ms/step - accuracy: 0.7817 - loss: 0.6288 - val_accuracy: 0.7400 - val_loss: 0.9169
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 237ms/step - accuracy: 0.7952 - loss: 0.6291 - val_accuracy: 0.7200 - val_loss: 0.9654
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - accuracy: 0.8033 - loss: 0.5631 - val_accuracy: 0.7050 - val_loss: 0.9730
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 232ms/step - accuracy: 0.8174 - loss: 0.5220 - val_accuracy: 0.7600 - val_loss: 0.9074
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 247ms/step - accuracy: 0.8303 - loss: 0.4855 - val_accuracy: 0.7300 - val_loss: 0.9109
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 190ms/step - accuracy: 0.8322 - loss: 0.5197 - val_accuracy: 0.6900 - val_loss: 0.9833
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 236ms/step - accuracy: 0.8231 - loss: 0.5361 - val_accuracy: 0.7250 - val_loss: 0.8728
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 226ms/step - accuracy: 0.8376 - loss: 0.4914 - val_accuracy: 0.7200 - val_loss: 0.9203
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 193ms/step - accuracy: 0.8304 - loss: 0.4963 - val_accuracy: 0.7500 - val_loss: 0.9434
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 236ms/step - accuracy: 0.8725 - loss: 0.4158 - val_accuracy: 0.7850 - val_loss: 0.7595
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 216ms/step - accuracy: 0.8632 - loss: 0.3871 - val_accuracy: 0.7700 - val_loss: 0.8295
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.8816 - loss: 0.3580 - val_accuracy: 0.7600 - val_loss: 0.9135
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 237ms/step - accuracy: 0.8760 - loss: 0.3725 - val_accuracy: 0.7650 - val_loss: 0.9409
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 226ms/step - accuracy: 0.8833 - loss: 0.3389 - val_accuracy: 0.7250 - val_loss: 0.9727
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 190ms/step - accuracy: 0.8851 - loss: 0.3359 - val_accuracy: 0.7600 - val_loss: 0.9128
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 239ms/step - accuracy: 0.8988 - loss: 0.2970 - val_accuracy: 0.7200 - val_loss: 1.0010
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 279ms/step - accuracy: 0.8865 - loss: 0.3416 - val_accuracy: 0.7300 - val_loss: 0.9524
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 193ms/step - accuracy: 0.9171 - loss: 0.2426 - val_accuracy: 0.7400 - val_loss: 0.9521
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 236ms/step - accuracy: 0.9141 - loss: 0.2706 - val_accuracy: 0.7700 - val_loss: 0.9076
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 220ms/step - accuracy: 0.9018 - loss: 0.2816 - val_accuracy: 0.7550 - val_loss: 0.9367
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 195ms/step - accuracy: 0.9266 - loss: 0.2218 - val_accuracy: 0.7400 - val_loss: 0.9741
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 238ms/step - accuracy: 0.8921 - loss: 0.2975 - val_accuracy: 0.7600 - val_loss: 1.0336
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - accuracy: 0.8956 - loss: 0.3253 - val_accuracy: 0.7450 - val_loss: 0.9493
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 236ms/step - accuracy: 0.9497 - loss: 0.1901 - val_accuracy: 0.7650 - val_loss: 0.9435
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 197ms/step - accuracy: 0.9175 - loss: 0.2231 - val_accuracy: 0.7450 - val_loss: 1.0181
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 237ms/step - accuracy: 0.9082 - loss: 0.2719 - val_accuracy: 0.7500 - val_loss: 0.9164
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - accuracy: 0.9377 - loss: 0.1896 - val_accuracy: 0.7450 - val_loss: 1.0693
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 195ms/step - accuracy: 0.9091 - loss: 0.2664 - val_accuracy: 0.7850 - val_loss: 0.9408
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 236ms/step - accuracy: 0.9294 - loss: 0.2231 - val_accuracy: 0.6950 - val_loss: 1.1799
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 235ms/step - accuracy: 0.9174 - loss: 0.2392 - val_accuracy: 0.7350 - val_loss: 1.0395
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 195ms/step - accuracy: 0.9127 - loss: 0.2941 - val_accuracy: 0.7500 - val_loss: 1.0278
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 236ms/step - accuracy: 0.9441 - loss: 0.1640 - val_accuracy: 0.7550 - val_loss: 1.1065
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 222ms/step - accuracy: 0.9154 - loss: 0.2153 - val_accuracy: 0.7250 - val_loss: 1.1111
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.9121 - loss: 0.2589 - val_accuracy: 0.7750 - val_loss: 1.0876
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - accuracy: 0.9581 - loss: 0.1519 - val_accuracy: 0.7700 - val_loss: 1.0389
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 234ms/step - accuracy: 0.9512 - loss: 0.1800 - val_accuracy: 0.7250 - val_loss: 1.0608
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 228ms/step - accuracy: 0.9331 - loss: 0.1957 - val_accuracy: 0.7350 - val_loss: 1.0912
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 194ms/step - accuracy: 0.9441 - loss: 0.1758 - val_accuracy: 0.7650 - val_loss: 1.1090
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 238ms/step - accuracy: 0.9527 - loss: 0.1473 - val_accuracy: 0.7550 - val_loss: 1.1828
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 233ms/step - accuracy: 0.9426 - loss: 0.1941 - val_accuracy: 0.7150 - val_loss: 1.1525
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 194ms/step - accuracy: 0.9405 - loss: 0.1686 - val_accuracy: 0.7550 - val_loss: 1.2208
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7492 - loss: 1.2606
# Test Accuracy: 75.50%
